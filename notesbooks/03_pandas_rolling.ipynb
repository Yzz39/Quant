# %%
import pandas as pd

df = pd.read_csv("../data/sample_etf_daily.csv")

df["date"]=pd.to_datetime(df["date"])
df["close"]=pd.to_numeric(df["close"],errors="coerce")

df=df.sort_values(["symbol","date"])
df["ma20"]=df["close"].rolling(20).mean()
df["ma60"]=df["close"].rolling(60).mean()
df["ret"]=df.groupby("symbol")["close"].pct_change()
df["signal"]=df["close"]>df["ma20"]
df["strategy_ret"]=df["signal"].shift(1) * df["ret"]

print(df[["date","symbol","strategy_ret"]])
# Out:
#       symbol strategy_ret
# 0     159915          NaN
# 3     159915         -0.0
# 6     159915         -0.0
# 9     159915         -0.0
# 12    159915         -0.0
# ...      ...          ...
# 1553  511010     0.001474
# 1556  511010    -0.003574
# 1559  511010    -0.000142
# 1562  511010    -0.002519
# 1565  511010     0.000616
#
# [1566 rows x 2 columns]
